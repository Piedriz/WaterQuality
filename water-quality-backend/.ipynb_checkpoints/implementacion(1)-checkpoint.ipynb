# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
from sklearn.model_selection import (
    KFold,
    train_test_split,
    GridSearchCV,
)
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import r2_score

# %% [markdown]
# CARGANDO EL CONJUNTO DE DATOS

# %%
dfwater = pd.read_csv('water_potability.csv')
dfwater.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %% [markdown]
# DIOMENSIONES DEL DATASET

# %%
dfwater.shape
# Out:
# (3276, 10)

# %% [markdown]
# REVISANDO EL CONTENIDO DEL DATASET

# %%
dfwater.head(20)
# Out:
#            ph    Hardness        Solids  Chloramines     Sulfate  \
# 0         NaN  204.890455  20791.318981     7.300212  368.516441
# 1    3.716080  129.422921  18630.057858     6.635246         NaN
# 2    8.099124  224.236259  19909.541732     9.275884         NaN
# 3    8.316766  214.373394  22018.417441     8.059332  356.886136
# 4    9.092223  181.101509  17978.986339     6.546600  310.135738
# 5    5.584087  188.313324  28748.687739     7.544869  326.678363
# 6   10.223862  248.071735  28749.716544     7.513408  393.663396
# 7    8.635849  203.361523  13672.091764     4.563009  303.309771
# 8         NaN  118.988579  14285.583854     7.804174  268.646941
# 9   11.180284  227.231469  25484.508491     9.077200  404.041635
# 10   7.360640  165.520797  32452.614409     7.550701  326.624353
# 11   7.974522  218.693300  18767.656682     8.110385         NaN
# 12   7.119824  156.704993  18730.813653     3.606036  282.344050
# 13        NaN  150.174923  27331.361962     6.838223  299.415781
# 14   7.496232  205.344982  28388.004887     5.072558         NaN
# 15   6.347272  186.732881  41065.234765     9.629596  364.487687
# 16   7.051786  211.049406  30980.600787    10.094796         NaN
# 17   9.181560  273.813807  24041.326280     6.904990  398.350517
# 18   8.975464  279.357167  19460.398131     6.204321         NaN
# 19   7.371050  214.496610  25630.320037     4.432669  335.754439
#
#     Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0     564.308654       10.379783        86.990970   2.963135           0
# 1     592.885359       15.180013        56.329076   4.500656           0
# 2     418.606213       16.868637        66.420093   3.055934           0
# 3     363.266516       18.436524       100.341674   4.628771           0
# 4     398.410813       11.558279        31.997993   4.075075           0
# 5     280.467916        8.399735        54.917862   2.559708           0
# 6     283.651634       13.789695        84.603556   2.672989           0
# 7     474.607645       12.363817        62.798309   4.401425           0
# 8     389.375566       12.706049        53.928846   3.595017           0
# 9     563.885481       17.927806        71.976601   4.370562           0
# 10    425.383419       15.586810        78.740016   3.662292           0
# 11    364.098230       14.525746        76.485911   4.011718           0
# 12    347.715027       15.929536        79.500778   3.445756           0
# 13    379.761835       19.370807        76.509996   4.413974           0
# 14    444.645352       13.228311        70.300213   4.777382           0
# 15    516.743282       11.539781        75.071617   4.376348           0
# 16    315.141267       20.397022        56.651604   4.268429           0
# 17    477.974642       13.387341        71.457362   4.503661           0
# 18    431.443990       12.888759        63.821237   2.436086           0
# 19    469.914551       12.509164        62.797277   2.560299           0

# %%
dfwater.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
dfwater['Potability'].value_counts()
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64

# %% [markdown]
# GRAFICANDO LOS DATOS

# %%
ax=plt.subplots(1,1,figsize=(10,8))
sns.countplot(x='Potability',data=dfwater,palette="Set2")
plt.title("Potabilidad")
plt.show()

# %%
dfwater.hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(12,12)
plt.show()

# %%
i=1
plt.figure(figsize=(15,25))
for feature in dfwater.columns:
    plt.subplot(6,3,i)
    sns.boxplot(y=dfwater[feature])
    i+=1

# %% [markdown]
# VIENDO LA CORRELACION DE LOS DATOS

# %%
plt.figure(figsize=(20, 15))
corr_matrix = dfwater.corr()
heatmap = sns.heatmap(corr_matrix, annot=True)

# %%
print(corr_matrix['Potability'].sort_values(ascending = False),'\n')
# Out:
# Potability         1.000000
# Solids             0.033743
# Chloramines        0.023779
# Trihalomethanes    0.007130
# Turbidity          0.001581
# ph                -0.003556
# Conductivity      -0.008128
# Hardness          -0.013837
# Sulfate           -0.023577
# Organic_carbon    -0.030001
# Name: Potability, dtype: float64

# %% [markdown]
# BUSCANDO REGISTROS CON VALORES VACIOS

# %%
dfwater.isna().sum().sort_values()
# Out:
# Hardness             0
# Solids               0
# Chloramines          0
# Conductivity         0
# Organic_carbon       0
# Turbidity            0
# Potability           0
# Trihalomethanes    162
# ph                 491
# Sulfate            781
# dtype: int64

# %% [markdown]
# CORRGIENDO LOS REGISTROS CON VALORES VACIOS

# %%
dfwater['Trihalomethanes'].fillna(value=dfwater['Trihalomethanes'].median(), inplace=True)
dfwater['ph'].fillna(value=dfwater['ph'].median(), inplace=True)
dfwater['Sulfate'].fillna(value=dfwater['Sulfate'].median(), inplace=True)

# %%
dfwater.head(20)
# Out:
#            ph    Hardness        Solids  Chloramines     Sulfate  \
# 0    7.036752  204.890455  20791.318981     7.300212  368.516441
# 1    3.716080  129.422921  18630.057858     6.635246  333.073546
# 2    8.099124  224.236259  19909.541732     9.275884  333.073546
# 3    8.316766  214.373394  22018.417441     8.059332  356.886136
# 4    9.092223  181.101509  17978.986339     6.546600  310.135738
# 5    5.584087  188.313324  28748.687739     7.544869  326.678363
# 6   10.223862  248.071735  28749.716544     7.513408  393.663396
# 7    8.635849  203.361523  13672.091764     4.563009  303.309771
# 8    7.036752  118.988579  14285.583854     7.804174  268.646941
# 9   11.180284  227.231469  25484.508491     9.077200  404.041635
# 10   7.360640  165.520797  32452.614409     7.550701  326.624353
# 11   7.974522  218.693300  18767.656682     8.110385  333.073546
# 12   7.119824  156.704993  18730.813653     3.606036  282.344050
# 13   7.036752  150.174923  27331.361962     6.838223  299.415781
# 14   7.496232  205.344982  28388.004887     5.072558  333.073546
# 15   6.347272  186.732881  41065.234765     9.629596  364.487687
# 16   7.051786  211.049406  30980.600787    10.094796  333.073546
# 17   9.181560  273.813807  24041.326280     6.904990  398.350517
# 18   8.975464  279.357167  19460.398131     6.204321  333.073546
# 19   7.371050  214.496610  25630.320037     4.432669  335.754439
#
#     Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0     564.308654       10.379783        86.990970   2.963135           0
# 1     592.885359       15.180013        56.329076   4.500656           0
# 2     418.606213       16.868637        66.420093   3.055934           0
# 3     363.266516       18.436524       100.341674   4.628771           0
# 4     398.410813       11.558279        31.997993   4.075075           0
# 5     280.467916        8.399735        54.917862   2.559708           0
# 6     283.651634       13.789695        84.603556   2.672989           0
# 7     474.607645       12.363817        62.798309   4.401425           0
# 8     389.375566       12.706049        53.928846   3.595017           0
# 9     563.885481       17.927806        71.976601   4.370562           0
# 10    425.383419       15.586810        78.740016   3.662292           0
# 11    364.098230       14.525746        76.485911   4.011718           0
# 12    347.715027       15.929536        79.500778   3.445756           0
# 13    379.761835       19.370807        76.509996   4.413974           0
# 14    444.645352       13.228311        70.300213   4.777382           0
# 15    516.743282       11.539781        75.071617   4.376348           0
# 16    315.141267       20.397022        56.651604   4.268429           0
# 17    477.974642       13.387341        71.457362   4.503661           0
# 18    431.443990       12.888759        63.821237   2.436086           0
# 19    469.914551       12.509164        62.797277   2.560299           0

# %%
dfwater.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %% [markdown]
# NIVELANDO LOS DATOS

# %%
y_target = dfwater['Potability']
x_data = dfwater.drop(['Potability'], axis=1)
smt = SMOTE(random_state=42)
x_data, y_target = smt.fit_resample(x_data, y_target)
sns.countplot(y_target)
# Out:
# c:\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Potability', ylabel='count'>

# %% [markdown]
# ESCALANDO LOS DATOS

# %%
scaler = MinMaxScaler()
x_data = pd.DataFrame(scaler.fit_transform(x_data), columns =x_data.columns.to_list())

# %% [markdown]
# DIVIENDO EL CONJUNTO DE DATOS PARA ENTRENAMIENTO Y PRUEBA

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_target, test_size=0.2)

# %% [markdown]
# APLICANDO RANDOM FOREST

# %%
# Random Forest Classifier
ModeloRf = RandomForestClassifier()

# hyperparameter space
param_grid = dict(
    n_estimators = [135,140,145],
    max_depth = [20,25,30],
    min_samples_split = [4,5,6]
)

# K-Fold Cross-Validation
kf = KFold(n_splits=5, shuffle=True, random_state=4)

# search
clf =  GridSearchCV(
    ModeloRf,
    param_grid,
    scoring='accuracy',
    cv=kf, # k-fold
    refit=True, # refits best model to entire dataset
)

search = clf.fit(x_train, y_train)

# best hyperparameters
search.best_params_
# Out:
# {'max_depth': 25, 'min_samples_split': 4, 'n_estimators': 145}

# %%
results = pd.DataFrame(search.cv_results_)[['params', 'mean_test_score', 'std_test_score']]
print(results.shape)
results
# Out:
# (27, 3)
#                                                params  mean_test_score  \
# 0   {'max_depth': 20, 'min_samples_split': 4, 'n_e...         0.686473
# 1   {'max_depth': 20, 'min_samples_split': 4, 'n_e...         0.672398
# 2   {'max_depth': 20, 'min_samples_split': 4, 'n_e...         0.685846
# 3   {'max_depth': 20, 'min_samples_split': 5, 'n_e...         0.677710
# 4   {'max_depth': 20, 'min_samples_split': 5, 'n_e...         0.686473
# 5   {'max_depth': 20, 'min_samples_split': 5, 'n_e...         0.678966
# 6   {'max_depth': 20, 'min_samples_split': 6, 'n_e...         0.684285
# 7   {'max_depth': 20, 'min_samples_split': 6, 'n_e...         0.675520
# 8   {'max_depth': 20, 'min_samples_split': 6, 'n_e...         0.686477
# 9   {'max_depth': 25, 'min_samples_split': 4, 'n_e...         0.680524
# 10  {'max_depth': 25, 'min_samples_split': 4, 'n_e...         0.684599
# 11  {'max_depth': 25, 'min_samples_split': 4, 'n_e...         0.692417
# 12  {'max_depth': 25, 'min_samples_split': 5, 'n_e...         0.685849
# 13  {'max_depth': 25, 'min_samples_split': 5, 'n_e...         0.689291
# 14  {'max_depth': 25, 'min_samples_split': 5, 'n_e...         0.685533
# 15  {'max_depth': 25, 'min_samples_split': 6, 'n_e...         0.686473
# 16  {'max_depth': 25, 'min_samples_split': 6, 'n_e...         0.682721
# 17  {'max_depth': 25, 'min_samples_split': 6, 'n_e...         0.677086
# 18  {'max_depth': 30, 'min_samples_split': 4, 'n_e...         0.688663
# 19  {'max_depth': 30, 'min_samples_split': 4, 'n_e...         0.689917
# 20  {'max_depth': 30, 'min_samples_split': 4, 'n_e...         0.690223
# 21  {'max_depth': 30, 'min_samples_split': 5, 'n_e...         0.680218
# 22  {'max_depth': 30, 'min_samples_split': 5, 'n_e...         0.685218
# 23  {'max_depth': 30, 'min_samples_split': 5, 'n_e...         0.683032
# 24  {'max_depth': 30, 'min_samples_split': 6, 'n_e...         0.676148
# 25  {'max_depth': 30, 'min_samples_split': 6, 'n_e...         0.684282
# 26  {'max_depth': 30, 'min_samples_split': 6, 'n_e...         0.685849
#
#     std_test_score
# 0         0.019354
# 1         0.010184
# 2         0.021412
# 3         0.021161
# 4         0.018420
# 5         0.014213
# 6         0.014042
# 7         0.023844
# 8         0.013029
# 9         0.026399
# 10        0.013630
# 11        0.018564
# 12        0.015405
# 13        0.016952
# 14        0.019737
# 15        0.018153
# 16        0.013990
# 17        0.016987
# 18        0.016822
# 19        0.012194
# 20        0.023311
# 21        0.013386
# 22        0.024103
# 23        0.016738
# 24        0.016580
# 25        0.019435
# 26        0.013936

# %% [markdown]
# MOSTRANDO RESULTADOS Y MATRIZ DE CONFUSION

# %%
# let's get the predictions
train_preds = search.predict(x_train)
test_preds = search.predict(x_test)

print('Train Accuracy: ', accuracy_score(y_train, train_preds))
print('Test Accuracy: ', accuracy_score(y_test, test_preds))
print("Confusion matrix:\n%s" % confusion_matrix(y_test, test_preds))
# Out:
# Train Accuracy:  1.0
# Test Accuracy:  0.71125
# Confusion matrix:
# [[307 116]
#  [115 262]]

# %% [markdown]
# APLICANDO ARBOLES DE DECISION

# %%
# Decision Tree Classifier
dtc = DecisionTreeClassifier()

# hyperparameter space
param_grid = dict(
    max_depth = [25,30,35],
    min_samples_split = [4,5,6]
)

# K-Fold Cross-Validation
kf = KFold(n_splits=5, shuffle=True, random_state=4)

# search
clf =  GridSearchCV(
    dtc,
    param_grid,
    scoring='accuracy',
    cv=kf, # k-fold
    refit=True, # refits best model to entire dataset
)

search = clf.fit(x_train, y_train)


# best hyperparameters
search.best_params_
# Out:
# {'max_depth': 35, 'min_samples_split': 6}

# %%
results = pd.DataFrame(search.cv_results_)[['params', 'mean_test_score', 'std_test_score']]
print(results.shape)
results
# Out:
# (9, 3)
#                                       params  mean_test_score  std_test_score
# 0  {'max_depth': 25, 'min_samples_split': 4}         0.585419        0.019025
# 1  {'max_depth': 25, 'min_samples_split': 5}         0.587294        0.011869
# 2  {'max_depth': 25, 'min_samples_split': 6}         0.586043        0.011775
# 3  {'max_depth': 30, 'min_samples_split': 4}         0.591675        0.016570
# 4  {'max_depth': 30, 'min_samples_split': 5}         0.584479        0.012857
# 5  {'max_depth': 30, 'min_samples_split': 6}         0.584791        0.017082
# 6  {'max_depth': 35, 'min_samples_split': 4}         0.587922        0.010717
# 7  {'max_depth': 35, 'min_samples_split': 5}         0.593238        0.013886
# 8  {'max_depth': 35, 'min_samples_split': 6}         0.593550        0.015541

# %% [markdown]
# MOSTRANDO RESULTADOS Y MATRIZ DE CONFUSION

# %%
# let's get the predictions
train_preds = search.predict(x_train)
test_preds = search.predict(x_test)

print('Train Accuracy: ', accuracy_score(y_train, train_preds))
print('Test Accuracy: ', accuracy_score(y_test, test_preds))

print("Confusion matrix:\n%s" % confusion_matrix(y_test, test_preds))
# Out:
# Train Accuracy:  0.9596370463078848
# Test Accuracy:  0.6225
# Confusion matrix:
# [[264 159]
#  [143 234]]

# %% [markdown]
# APLICANDO UN PERCEPTRON MULTICAPAS

# %%
model_MPL = MLPClassifier()
MPL_parameters = [{'hidden_layer_sizes' : [(50,50),(50, 50, 50), (75, 75, 50)], 
                   'max_iter':[1500, 2000,2500], 
                   'alpha': [0.001, 0.01]}]
                   
# K-Fold Cross-Validation
kf = KFold(n_splits=5, shuffle=True, random_state=4)

grid_MPL = GridSearchCV(model_MPL, MPL_parameters, cv=kf, scoring='neg_mean_squared_error')
grid_result_MPL = grid_MPL.fit(x_train, y_train)
print(grid_result_MPL.best_params_)
# Out:
# {'alpha': 0.001, 'hidden_layer_sizes': (75, 75, 50), 'max_iter': 2500}

# %% [markdown]
# MOSTRANDO RESULTADOS Y MATRIZ DE CONFUSION

# %%
train_preds = grid_result_MPL.predict(x_train)
test_preds = grid_result_MPL.predict(x_test)
print('Train Accuracy: ', accuracy_score(y_train, train_preds))
print('Test Accuracy: ', accuracy_score(y_test, test_preds))
print("Confusion matrix:\n%s" % confusion_matrix(y_test, test_preds))
# Out:
# Train Accuracy:  0.7393617021276596
# Test Accuracy:  0.64875
# Confusion matrix:
# [[245 178]
#  [103 274]]

# %% [markdown]
# DIVIDIENDO LOS DATOS EN ENTRENAMIENTO Y VALIDACION

# %%
np.random.seed(42)
tf.random.set_seed(42)
Xtrain2, Xvalid, Ytrain2, Yvalid = train_test_split(x_train, y_train, random_state=42)
print("Los datos de entrenamiento contienen %d registros " % (len(Xtrain2)))
print("Los datos de prueba contienen %d registros " % (len(Xvalid)))
# Out:
# Los datos de entrenamiento contienen 2397 registros
# Los datos de prueba contienen 799 registros

# %% [markdown]
# APLICANDO KERAS

# %%
model = keras.models.Sequential([
    keras.layers.Dense(75, activation="relu", input_shape = x_train.shape[1:]),
    keras.layers.Dense(75, activation="relu"),
    keras.layers.Dense(50, activation="relu"),
    keras.layers.Dense(1)
])
model.compile(loss="mean_squared_error", optimizer=keras.optimizers.SGD(learning_rate=1e-3),metrics='accuracy')
history = model.fit(Xtrain2, Ytrain2, epochs=100, validation_data=(Xvalid, Yvalid))

mse_test = model.evaluate(x_test, y_test)
print('MSE con datos de prueba is {}'.format(mse_test))
# Out:
# Epoch 1/100
# 75/75 [==============================] - 1s 4ms/step - loss: 0.4220 - accuracy: 0.4910 - val_loss: 0.3479 - val_accuracy: 0.4981
# Epoch 2/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3179 - accuracy: 0.4910 - val_loss: 0.2879 - val_accuracy: 0.4981
# Epoch 3/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2766 - accuracy: 0.4910 - val_loss: 0.2636 - val_accuracy: 0.4981
# Epoch 4/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2601 - accuracy: 0.4910 - val_loss: 0.2546 - val_accuracy: 0.4969
# Epoch 5/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2538 - accuracy: 0.4877 - val_loss: 0.2516 - val_accuracy: 0.4994
# Epoch 6/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2517 - accuracy: 0.4881 - val_loss: 0.2506 - val_accuracy: 0.4994
# Epoch 7/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2509 - accuracy: 0.4956 - val_loss: 0.2503 - val_accuracy: 0.4944
# Epoch 8/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2506 - accuracy: 0.4969 - val_loss: 0.2503 - val_accuracy: 0.4956
# Epoch 9/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2505 - accuracy: 0.5048 - val_loss: 0.2502 - val_accuracy: 0.4906
# Epoch 10/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2504 - accuracy: 0.5056 - val_loss: 0.2502 - val_accuracy: 0.4956
# Epoch 11/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2504 - accuracy: 0.5040 - val_loss: 0.2502 - val_accuracy: 0.4956
# Epoch 12/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2503 - accuracy: 0.5069 - val_loss: 0.2502 - val_accuracy: 0.4994
# Epoch 13/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2503 - accuracy: 0.5115 - val_loss: 0.2501 - val_accuracy: 0.4994
# Epoch 14/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2502 - accuracy: 0.5086 - val_loss: 0.2501 - val_accuracy: 0.4969
# Epoch 15/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2502 - accuracy: 0.5060 - val_loss: 0.2501 - val_accuracy: 0.4981
# Epoch 16/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2502 - accuracy: 0.5040 - val_loss: 0.2501 - val_accuracy: 0.4944
# Epoch 17/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2501 - accuracy: 0.5081 - val_loss: 0.2500 - val_accuracy: 0.4956
# Epoch 18/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2501 - accuracy: 0.5065 - val_loss: 0.2500 - val_accuracy: 0.4944
# Epoch 19/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2501 - accuracy: 0.5044 - val_loss: 0.2500 - val_accuracy: 0.4956
# Epoch 20/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.5069 - val_loss: 0.2500 - val_accuracy: 0.4956
# Epoch 21/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.5031 - val_loss: 0.2499 - val_accuracy: 0.4994
# Epoch 22/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.5073 - val_loss: 0.2499 - val_accuracy: 0.4969
# Epoch 23/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2499 - accuracy: 0.5048 - val_loss: 0.2499 - val_accuracy: 0.5006
# Epoch 24/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2499 - accuracy: 0.5052 - val_loss: 0.2499 - val_accuracy: 0.4994
# Epoch 25/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2498 - accuracy: 0.5044 - val_loss: 0.2499 - val_accuracy: 0.4969
# Epoch 26/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2498 - accuracy: 0.5040 - val_loss: 0.2499 - val_accuracy: 0.4956
# Epoch 27/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2498 - accuracy: 0.5077 - val_loss: 0.2499 - val_accuracy: 0.4981
# Epoch 28/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2497 - accuracy: 0.5040 - val_loss: 0.2498 - val_accuracy: 0.4956
# Epoch 29/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2497 - accuracy: 0.5077 - val_loss: 0.2499 - val_accuracy: 0.4956
# Epoch 30/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2497 - accuracy: 0.5086 - val_loss: 0.2498 - val_accuracy: 0.4931
# Epoch 31/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2497 - accuracy: 0.5056 - val_loss: 0.2498 - val_accuracy: 0.4994
# Epoch 32/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2496 - accuracy: 0.5094 - val_loss: 0.2498 - val_accuracy: 0.4981
# Epoch 33/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2496 - accuracy: 0.5094 - val_loss: 0.2498 - val_accuracy: 0.4919
# Epoch 34/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2496 - accuracy: 0.5102 - val_loss: 0.2498 - val_accuracy: 0.5031
# Epoch 35/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2496 - accuracy: 0.5081 - val_loss: 0.2498 - val_accuracy: 0.5019
# Epoch 36/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2496 - accuracy: 0.5081 - val_loss: 0.2498 - val_accuracy: 0.5019
# Epoch 37/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2495 - accuracy: 0.5077 - val_loss: 0.2498 - val_accuracy: 0.4994
# Epoch 38/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2495 - accuracy: 0.5111 - val_loss: 0.2498 - val_accuracy: 0.5019
# Epoch 39/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2495 - accuracy: 0.5173 - val_loss: 0.2498 - val_accuracy: 0.4981
# Epoch 40/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2495 - accuracy: 0.5069 - val_loss: 0.2498 - val_accuracy: 0.5019
# Epoch 41/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2495 - accuracy: 0.5119 - val_loss: 0.2498 - val_accuracy: 0.5069
# Epoch 42/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2495 - accuracy: 0.5090 - val_loss: 0.2498 - val_accuracy: 0.5069
# Epoch 43/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.5102 - val_loss: 0.2498 - val_accuracy: 0.5044
# Epoch 44/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.5119 - val_loss: 0.2497 - val_accuracy: 0.5106
# Epoch 45/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.5115 - val_loss: 0.2497 - val_accuracy: 0.5119
# Epoch 46/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.5181 - val_loss: 0.2497 - val_accuracy: 0.5094
# Epoch 47/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.5186 - val_loss: 0.2498 - val_accuracy: 0.5044
# Epoch 48/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.5136 - val_loss: 0.2497 - val_accuracy: 0.5106
# Epoch 49/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.5127 - val_loss: 0.2497 - val_accuracy: 0.5056
# Epoch 50/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.5119 - val_loss: 0.2497 - val_accuracy: 0.5094
# Epoch 51/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.5144 - val_loss: 0.2497 - val_accuracy: 0.5094
# Epoch 52/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.5111 - val_loss: 0.2497 - val_accuracy: 0.5081
# Epoch 53/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.5186 - val_loss: 0.2497 - val_accuracy: 0.5106
# Epoch 54/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.5181 - val_loss: 0.2497 - val_accuracy: 0.5106
# Epoch 55/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2492 - accuracy: 0.5106 - val_loss: 0.2497 - val_accuracy: 0.5181
# Epoch 56/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2492 - accuracy: 0.5190 - val_loss: 0.2497 - val_accuracy: 0.5131
# Epoch 57/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2492 - accuracy: 0.5161 - val_loss: 0.2496 - val_accuracy: 0.5131
# Epoch 58/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2492 - accuracy: 0.5177 - val_loss: 0.2496 - val_accuracy: 0.5106
# Epoch 59/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2492 - accuracy: 0.5198 - val_loss: 0.2496 - val_accuracy: 0.5144
# Epoch 60/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2492 - accuracy: 0.5223 - val_loss: 0.2496 - val_accuracy: 0.5181
# Epoch 61/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2492 - accuracy: 0.5211 - val_loss: 0.2496 - val_accuracy: 0.5094
# Epoch 62/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.5223 - val_loss: 0.2496 - val_accuracy: 0.5156
# Epoch 63/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.5190 - val_loss: 0.2496 - val_accuracy: 0.5094
# Epoch 64/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.5161 - val_loss: 0.2496 - val_accuracy: 0.5106
# Epoch 65/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.5223 - val_loss: 0.2496 - val_accuracy: 0.5119
# Epoch 66/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.5244 - val_loss: 0.2496 - val_accuracy: 0.5144
# Epoch 67/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.5207 - val_loss: 0.2496 - val_accuracy: 0.5119
# Epoch 68/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.5211 - val_loss: 0.2496 - val_accuracy: 0.5106
# Epoch 69/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.5261 - val_loss: 0.2496 - val_accuracy: 0.5207
# Epoch 70/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.5236 - val_loss: 0.2496 - val_accuracy: 0.5144
# Epoch 71/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.5227 - val_loss: 0.2495 - val_accuracy: 0.5181
# Epoch 72/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.5215 - val_loss: 0.2495 - val_accuracy: 0.5156
# Epoch 73/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.5223 - val_loss: 0.2495 - val_accuracy: 0.5156
# Epoch 74/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.5240 - val_loss: 0.2495 - val_accuracy: 0.5181
# Epoch 75/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.5265 - val_loss: 0.2495 - val_accuracy: 0.5169
# Epoch 76/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.5257 - val_loss: 0.2495 - val_accuracy: 0.5169
# Epoch 77/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.5227 - val_loss: 0.2495 - val_accuracy: 0.5181
# Epoch 78/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.5219 - val_loss: 0.2495 - val_accuracy: 0.5156
# Epoch 79/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.5269 - val_loss: 0.2495 - val_accuracy: 0.5156
# Epoch 80/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.5294 - val_loss: 0.2495 - val_accuracy: 0.5207
# Epoch 81/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.5277 - val_loss: 0.2495 - val_accuracy: 0.5207
# Epoch 82/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.5269 - val_loss: 0.2494 - val_accuracy: 0.5194
# Epoch 83/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.5240 - val_loss: 0.2494 - val_accuracy: 0.5219
# Epoch 84/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.5277 - val_loss: 0.2494 - val_accuracy: 0.5257
# Epoch 85/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.5277 - val_loss: 0.2494 - val_accuracy: 0.5269
# Epoch 86/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.5273 - val_loss: 0.2494 - val_accuracy: 0.5181
# Epoch 87/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.5286 - val_loss: 0.2494 - val_accuracy: 0.5194
# Epoch 88/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.5261 - val_loss: 0.2494 - val_accuracy: 0.5169
# Epoch 89/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.5323 - val_loss: 0.2494 - val_accuracy: 0.5207
# Epoch 90/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.5257 - val_loss: 0.2494 - val_accuracy: 0.5194
# Epoch 91/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.5315 - val_loss: 0.2494 - val_accuracy: 0.5269
# Epoch 92/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.5327 - val_loss: 0.2493 - val_accuracy: 0.5156
# Epoch 93/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.5298 - val_loss: 0.2493 - val_accuracy: 0.5194
# Epoch 94/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.5323 - val_loss: 0.2493 - val_accuracy: 0.5194
# Epoch 95/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.5286 - val_loss: 0.2493 - val_accuracy: 0.5181
# Epoch 96/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.5286 - val_loss: 0.2493 - val_accuracy: 0.5181
# Epoch 97/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.5269 - val_loss: 0.2493 - val_accuracy: 0.5194
# Epoch 98/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.5311 - val_loss: 0.2493 - val_accuracy: 0.5232
# Epoch 99/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.5315 - val_loss: 0.2493 - val_accuracy: 0.5219
# Epoch 100/100
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.5323 - val_loss: 0.2493 - val_accuracy: 0.5156
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2513 - accuracy: 0.4913
# MSE con datos de prueba is [0.2512543201446533, 0.49125000834465027]
